# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

'''
params = {"ytick.color" : "black",
          "xtick.color" : "black",
          "axes.labelcolor" : "black",
          "axes.edgecolor" : "black",
          "text.usetex" : True,
          "font.family" : "serif",
          "font.serif" : ["Computer Modern Serif"]}
plt.rcParams.update(params)
'''
# Out:
# '\nparams = {"ytick.color" : "black",\n          "xtick.color" : "black",\n          "axes.labelcolor" : "black",\n          "axes.edgecolor" : "black",\n          "text.usetex" : True,\n          "font.family" : "serif",\n          "font.serif" : ["Computer Modern Serif"]}\nplt.rcParams.update(params)\n'

# %%
run="run1"
ratio="0.6"
mass = "0.05"
mass_label = "0.05"
dmode = "pi0"

if(run=="run1"):
    run_flag = "Run 1"
else:
    run_flag = "Run 3"

# %%
base_bkg = "/home/lmlepin/Desktop/dm_sets/dark_tridents_analysis/{}_samples/".format(run)
base_signal = "/home/lmlepin/Desktop/dm_sets/dark_tridents_analysis/{}_signal/".format(run)
figs_dir = "/home/lmlepin/Desktop/Plots_DT_Drive/2023/CNN_plots/"

# %%
df_signal = pd.read_csv(base_signal + "{}_dt_ratio_{}_{}_{}_CNN_scores_8441_steps.csv".format(run,ratio,mass,dmode))


mass = int(float(mass)*1000)
mass = str(mass)

df_signal = df_signal[df_signal['signal_score'] >= 0.]

nbins = 50
fig = plt.figure(figsize=(19,16),dpi=300)

ax = fig.add_subplot(111)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.5)  # change width
    ax.spines[axis].set_color('black')    # change color
    
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

bins_x = np.linspace(0.,1.,nbins)
bins_y = np.linspace(0.,1.5, nbins)
hist, xbins, ybins, im = plt.hist2d(df_signal['signal_score'],
                                    df_signal['reco_shower_energy_max']/1000.,bins=(bins_x,bins_y),cmap='jet')



mean_per_x_bin = np.mean(hist,axis=0)
'''              
for i in range(len(ybins)-1):
    for j in range(len(xbins)-1):
        plt.text(xbins[j]+0.5,ybins[i]+0.5, round(int(hist.T[i,j])/(len(df)), 2) , 
                color="white", ha="center", va="center", fontweight="bold", fontsize=15)
'''

title_label = r"$M_{A'}=$ " + mass + " [MeV]              $M_{\chi}/M_{A'}=$ " + ratio
plt.title(title_label,fontsize=45,pad=20)
plt.tick_params(axis="y", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="y", which='minor', direction="in",length=10,width=1.0,labelleft=False)
plt.tick_params(axis="x", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="x", which='minor', direction="in",length=10,width=2.0,labelbottom=False)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.xlim(0,1.)
plt.ylim(0,1.5)
plt.xlabel('Signal score',fontsize=45,labelpad=20)
plt.ylabel('Reconstructed energy [GeV]',fontsize=45,labelpad=20)
plt.savefig(figs_dir + "energy_vs_signal_score_ma_{}.png".format(mass_label),bbox_inches="tight")
plt.savefig(figs_dir + "energy_vs_signal_score_ma_{}.pdf".format(mass_label),bbox_inches="tight")
plt.show()

# %%
nbins = 25
fig = plt.figure(figsize=(19,16),dpi=300)

ax = fig.add_subplot(111)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.5)  # change width
    ax.spines[axis].set_color('black')    # change color
    
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

bins_x = np.linspace(0.,1.,nbins)
bins_y = np.linspace(0.,np.max(df_signal['n_pixels']), nbins)
hist, xbins, ybins, im = plt.hist2d(df_signal['signal_score'],
                                    df_signal['n_pixels'],bins=(bins_x,bins_y),cmap='jet')



mean_per_x_bin = np.mean(hist,axis=0)
'''              
for i in range(len(ybins)-1):
    for j in range(len(xbins)-1):
        plt.text(xbins[j]+0.5,ybins[i]+0.5, round(int(hist.T[i,j])/(len(df)), 2) , 
                color="white", ha="center", va="center", fontweight="bold", fontsize=15)
'''

title_label = r"$M_{A'}=$ " + mass + " [MeV]              $M_{\chi}/M_{A'}=$ " + ratio
plt.title(title_label,fontsize=45,pad=20)
plt.tick_params(axis="y", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="y", which='minor', direction="in",length=10,width=1.0,labelleft=False)
plt.tick_params(axis="x", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="x", which='minor', direction="in",length=10,width=2.0,labelbottom=False)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.xlim(0,1.)
plt.ylim(0,6000)
plt.xlabel('Signal score',fontsize=45,labelpad=20)
plt.ylabel('Number of active pixels',fontsize=45,labelpad=20)
# Out:
# Text(0, 0.5, 'Number of active pixels')

# %%
nbins = 40
fig = plt.figure(figsize=(19,16),dpi=300)

ax = fig.add_subplot(111)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.5)  # change width
    ax.spines[axis].set_color('black')    # change color
    
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

nbins_y = 100

bins_x = np.linspace(0.,1.5,nbins)
bins_y = np.linspace(0.,np.max(df_signal['n_pixels']), nbins_y)
hist, xbins, ybins, im = plt.hist2d(df_signal['reco_shower_energy_max']/1000.,
                                    df_signal['n_pixels'],bins=(bins_x,bins_y),cmap='jet')


title_label = r"$M_{A'}=$ " + mass + " [MeV]              $M_{\chi}/M_{A'}=$ " + ratio
plt.title(title_label,fontsize=45,pad=20)
plt.tick_params(axis="y", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="y", which='minor', direction="in",length=10,width=1.0,labelleft=False)
plt.tick_params(axis="x", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="x", which='minor', direction="in",length=10,width=2.0,labelbottom=False)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.xlim(0,1.5)
plt.ylim(0,4000)
plt.xlabel('Reconstructed energy [GeV]',fontsize=45,labelpad=20)
plt.ylabel('Number of active pixels',fontsize=45,labelpad=20)
plt.savefig(figs_dir + "energy_vs_number_of_pixels_ma_{}.png".format(mass_label),bbox_inches="tight")
plt.savefig(figs_dir + "energy_vs_number_of_pixels_ma_{}.pdf".format(mass_label),bbox_inches="tight")
plt.show()

# %%
fig = plt.figure(figsize=(19,16),dpi=300)

ax = fig.add_subplot(111)

for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2.5)  # change width
    ax.spines[axis].set_color('black')    # change color
    
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

df_selected = df_signal[df_signal['signal_score'] >= 0.5]
df_rejected = df_signal[df_signal['signal_score'] < 0.5]
binning = np.linspace(0.,1.5,60)


#(counts_nominal,bins_nominal) = np.histogram(df_signal['reco_shower_energy_max']/1000.,bins=binning)
(counts_selected,bins_selected) = np.histogram(df_selected['reco_shower_energy_max']/1000.,bins=binning)
(counts_rejected,bins_rejected) = np.histogram(df_rejected['reco_shower_energy_max']/1000.,bins=binning)


plt.hist(bins_selected[:-1],bins=bins_selected,weights=counts_selected,
         histtype="stepfilled",color="red",density=True,alpha=0.3)

plt.hist(bins_selected[:-1],bins=bins_selected,weights=counts_selected,
         histtype="step",color="red",density=True,lw=3.5,label="Selected")

plt.hist(bins_rejected[:-1],bins=bins_rejected,weights=counts_rejected,
         histtype="stepfilled",color="blue",density=True,alpha=0.3)

plt.hist(bins_rejected[:-1],bins=bins_rejected,weights=counts_rejected,
         histtype="step",color="blue",density=True,lw=3.5,label="Rejected")

title_label = r"$M_{A'}=$ " + mass + " [MeV]              $M_{\chi}/M_{A'}=$ " + ratio
plt.title(title_label,fontsize=45,pad=20)
plt.tick_params(axis="y", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="y", which='minor', direction="in",length=10,width=1.0,labelleft=False)
plt.tick_params(axis="x", which='major', direction="in",length=20,width=2.5,pad=10)
plt.tick_params(axis="x", which='minor', direction="in",length=10,width=2.0,labelbottom=False)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.xlim(0,1.5)
plt.legend(fontsize=45)
#plt.ylim(0,4000)
plt.xlabel('Reconstructed energy [GeV]',fontsize=45,labelpad=20)
plt.ylabel('A.U',fontsize=45,labelpad=20)
plt.savefig(figs_dir + "energy_distribution_selected_rejected_ma_{}.png".format(mass_label),bbox_inches="tight")
plt.savefig(figs_dir + "energy_distribution_selected_rejected_ma_{}.pdf".format(mass_label),bbox_inches="tight")
plt.show()

# %%
df_selected = df_selected[df_selected['reco_shower_energy_max'] >= 300]
print(df_selected.head())
print(df_selected['reco_shower_energy_max'].head())
# Out:
#    entry  run_number  subrun_number  event_number  reco_vertex_size  \
# 0      3      5437.0           50.0        2545.0               1.0
# 3      6      5437.0           51.0        2584.0               1.0
# 5     20      5437.0           54.0        2750.0               1.0
# 7     29      5437.0           57.0        2890.0               1.0
# 9     39      5536.0           80.0        4024.0               1.0
#
#    reco_asso_showers  reco_asso_tracks  reco_vertex_x  reco_vertex_y  \
# 0                1.0               0.0     115.005295     -93.426361
# 3                1.0               0.0     183.975830     -82.432129
# 5                1.0               0.0      95.721199    -112.182610
# 7                1.0               0.0      59.251499     -49.540573
# 9                2.0               0.0     121.110580     -30.968582
#
#    reco_vertex_z  ...  mctruth_qsqr     mctruth_w  mctruth_daughters_startx  \
# ...

# %%
df_rejected = df_rejected[df_rejected['reco_shower_energy_max'] <= 250]
print(df_rejected.head())
print(df_rejected['reco_shower_energy_max'].head())
# Out:
#     entry  run_number  subrun_number  event_number  reco_vertex_size  \
# 8      33      5437.0           58.0        2921.0               1.0
# 10     40      5536.0           80.0        4027.0               1.0
# 11     41      5536.0           80.0        4049.0               1.0
# 18     53      5536.0           84.0        4218.0               1.0
# 69    209      5368.0           40.0        2032.0               1.0
#
#     reco_asso_showers  reco_asso_tracks  reco_vertex_x  reco_vertex_y  \
# 8                 1.0               0.0      81.115135     114.043983
# 10                1.0               0.0     241.958267      60.286224
# 11                1.0               0.0     135.578705       7.562728
# 18                2.0               0.0      14.994640     -73.317192
# 69                1.0               0.0      15.436792     105.090126
#
#     reco_vertex_z  ...  mctruth_qsqr     mctruth_w  mctruth_daughters_startx  \
# ...
