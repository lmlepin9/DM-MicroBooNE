# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
run = "run1"
mass = "0.2"
ratio = "0.6"
dmode = "eta"
base_dir = "/home/lmlepin/Desktop/dm_sets/dark_tridents_analysis/" + run + "_signal/" 
plots_dir = "/home/lmlepin/Desktop/Plots_DT_Drive/2023/"
df_signal = pd.read_csv(base_dir + "{}_dt_{}_{}_new_CNN_scores_8441_steps.csv".format(run,mass,dmode))
df_signal = df_signal.drop_duplicates()
df_signal = df_signal[df_signal['signal_score']>=0.]

# %%
plt.hist(df_signal['signal_score'],bins=100)
plt.show()

# %%
from df_utils import *
df = df_signal[df_signal['signal_score']>=0.5]
plt.figure(figsize=(10,8),dpi=300)
binning =  [ 0., 1.375, 2.75, 4.125, 11.]
plt.hist(logit_transform(df['signal_score']),bins=binning)
plt.show()

# %%
(counts_signal, bins_signal) = np.histogram(logit_transform(df['signal_score']), bins = binning)
plt.hist(bins_signal[:-1], bins = bins_signal,weights=counts_signal, histtype='step' ,fill=False, edgecolor='gold', linewidth='2.')
plt.show()
