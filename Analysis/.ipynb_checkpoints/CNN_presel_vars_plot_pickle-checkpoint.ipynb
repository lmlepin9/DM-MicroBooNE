# %%
import uproot as u
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from df_utils import *

# %%
run = "run1"
dm_type = "fermion"
mass = "0.05"
target_pot = 1.
signal_pot = {}

signal_correction = { "0.01":0.94903385, "0.02":1.03561568, "0.03":1.02326517, "0.04":1.00641579, 
                     "0.05":1.00650082, "0.06":1.01293082, "0.07":1.07433777, 
                     "0.08":1.10175345, "0.09":1.0415591 , "0.10":1.1014797}


if(dm_type == "fermion"):
    signal_pot = { "0.01":4.49230189e+20, "0.02":3.24986846e+21, "0.03":1.44413783e+22, 
                  "0.04":5.51306150e+22, "0.05":1.74805153e+23, "0.06":5.79056950e+23,
                  "0.07":1.48783150e+24, "0.08":4.41322940e+24, 
                  "0.09":9.92424735e+24, "0.10":2.27414738e+25}

else: 
    signal_pot = { "0.01":8.70545727e+21, "0.02": 9.48797710e+22, "0.03":4.86277630e+23, 
                  "0.04":1.94231827e+24, "0.05":8.19564834e+24, "0.06":2.06542023e+25,
                  "0.07":5.83217654e+25, "0.08":1.54999742e+26, 
                  "0.09":2.94329651e+26, "0.10":5.04481005e+26}


scalings_run1 = { "nu":1./2.35e21, "dirt":1.026*0.75/1.6e21, "beamoff": 0.98*(6230439.0/9186361.390000)}
scalings_run3 = { "nu":1./1.993661e21, "dirt":0.98*0.35/1.020e21, "beamoff": 1.40*2.909}

scalings = {}

if(run == "run1"):
    target_pot = 2.384e+20
    scalings = scalings_run1
    pot_label = r'                    $2.38\times10^{20}$ POT'
else:
    target_pot = 5.0e20
    scalings = scalings_run3
    pot_label = r'                    $5\times10^{20}$ POT'

signal_scaling = signal_correction[mass]*target_pot/signal_pot[mass]
nu_scaling = target_pot*scalings["nu"]
dirt_scaling = target_pot*scalings["dirt"]
offbeam_scaling = scalings["beamoff"]

# %%
def GetStatsUncert(df_a, weight_array,my_custom_bins,plot_var):
    (counts_df, bins_df) = np.histogram(df_a[plot_var], bins = my_custom_bins, weights=np.square(weight_array))
    return counts_df

# %%
base_dir = "/home/lmlepin/Desktop/dm_sets/dark_tridents_analysis/run1_samples/" 
plots_dir = "/home/lmlepin/Desktop/Plots_DT_Drive/2023/"

#df_signal = pd.read_csv(base_dir + "dt_overlay_"+ mass + "_CNN_scores_8441_steps.csv")
df_nu = pd.read_pickle(base_dir + run + "_nu_overlay_CNN.pkl")
df_dirt = pd.read_pickle(base_dir + run + "_dirt_CNN.pkl")
df_beamoff = pd.read_pickle(base_dir + run + "_offbeam_CNN.pkl")
df_beamon = pd.read_pickle(base_dir + run + "_beamon_CNN.pkl")

# Filter out RHC from beamoff, Not right, why if I include everything the data/MC is screwed? 
#df_beamoff=df_beamoff[df_beamoff['run_number'] < 6784]


MC_weight_branch(df_nu)
MC_weight_branch(df_dirt)

# %%
up_plot = 260.
down_plot = 0.
my_custom_bins = np.linspace(down_plot,up_plot,20)
variable = 'reco_vertex_x'

#(counts_signal, bins_signal) = np.histogram(df_signal[variable], bins = my_custom_bins)
(counts_nu, bins_nu) = np.histogram(df_nu[variable], bins = my_custom_bins, weights = df_nu['weight'])
(counts_dirt, bins_dirt) = np.histogram(df_dirt[variable], bins = my_custom_bins, weights = df_dirt['weight'])
(counts_beamoff, bins_beamoff) = np.histogram(df_beamoff[variable], bins = my_custom_bins)
(counts_beamon, bins_beamon) = np.histogram(df_beamon[variable], bins = my_custom_bins)


print("Showing results for: " + run)
#print("Number of dark tridents M_A="+str(mass)+" :" + str(np.sum(counts_signal)*signal_scaling))
print("Number of neutrinos: " + str(np.sum(counts_nu)*nu_scaling))
print("Number of dirt: " + str(np.sum(counts_dirt)*dirt_scaling))
print("Number of beam-off: " + str(np.sum(counts_beamoff)*offbeam_scaling))
print("Number of beam-on: " + str(np.sum(counts_beamon)))


nu_legend = r'in cryo $\nu$ ({:.2f})'.format(np.sum(counts_nu)*nu_scaling)
dirt_legend = r'out of cryo $\nu$ ({:.2f})'.format(np.sum(counts_dirt)*dirt_scaling)
beamoff_legend = r'beam-off ({:.2f})'.format(np.sum(counts_beamoff)*offbeam_scaling)
beamon_legend = r'beam-on ({:.2f})'.format(np.sum(counts_beamon))

stacked_colors = ["darkviolet","navy","deepskyblue"]
stacked_legend = [nu_legend, dirt_legend, beamoff_legend]
stacked_bins = [bins_nu[:-1], bins_dirt[:-1], bins_beamoff[:-1]]
stacked_list = [counts_nu*nu_scaling, counts_dirt*dirt_scaling, counts_beamoff*offbeam_scaling ]


# Getting stats error 
counts_bkg = counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling
stats_nu = GetStatsUncert(df_nu, df_nu['weight']*nu_scaling,my_custom_bins,variable)
stats_dirt = GetStatsUncert(df_dirt, df_dirt['weight']*dirt_scaling,my_custom_bins,variable)
stats_beamoff = GetStatsUncert(df_beamoff, np.ones(len(df_beamoff))*offbeam_scaling,my_custom_bins,variable)
stats_total = np.sqrt(stats_nu + stats_dirt + stats_beamoff)
stats_error = (stats_total)/(counts_bkg)
stats_up = counts_bkg + stats_total
stats_down = counts_bkg - stats_total



# Trick for right error band on histograms 
bins_err = np.copy(bins_nu)
bins_err = np.append(bins_err,[bins_err[-1] + (bins_err[2] - bins_err[1])])
stats_up = np.append(stats_up,[stats_up[-1],stats_up[-1] ])
stats_down = np.append(stats_down,[stats_down[-1],stats_up[-1]])


fig, ax = plt.subplots(2,1,figsize=(10,7),dpi=300,gridspec_kw={'height_ratios': [4, 1], 'hspace': 0.08})
ax[0].set_title(r'MicroBooNE NuMI data' + ' ' + run + ', ' + dm_type + ' DM' + pot_label ,fontsize=15)
#ax[0].hist(bins_nu[:-1], bins = bins_nu, weights = stats_up, histtype='stepfilled',color = 'gray',alpha=0.5)
ax[0].hist(stacked_bins, bins = bins_nu, weights = stacked_list, histtype='stepfilled',stacked=True, color = stacked_colors, edgecolor="darkred", label = stacked_legend)
ax[0].fill_between(bins_err, stats_up, stats_down,color='gray',alpha=0.3,step='post')
ax[0].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),counts_beamon,yerr=np.sqrt(counts_beamon),fmt='o', capsize=5, color='black',label=beamon_legend)
#plt.hist(bins_signal[:-1], bins = bins_signal,weights=counts_signal*signal_scaling*10, histtype='step',label=dt_legend ,fill=False, edgecolor='gold', linewidth='2.')
ax[0].legend(fontsize=10)
ax[0].tick_params(axis='y', which='major', labelsize=10)
ax[0].tick_params(axis='x',which='both', bottom=False,top=False,labelbottom=False)
ax[0].set_xlim(down_plot,up_plot)
ax[0].set_ylabel("Events",fontsize=15, labelpad=7) 


ratio = (counts_beamon)/(counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling )
ax[1].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),ratio,fmt='o',capsize=5,color='black')
ax[1].hlines(1.0,down_plot,up_plot,color='black',linewidth=0.8)
ax[1].hlines(1.25,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].hlines(0.75,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].tick_params(axis='both', which='major', labelsize=10)
ax[1].set_ylim(0.5,1.5)
ax[1].set_xlabel(r'Reconstructed vertex x-coordinate [cm]',fontsize=15,labelpad=7)
ax[1].set_xlim(down_plot,up_plot)
ax[1].set_ylabel(r'Data/MC',fontsize=15,labelpad=7)
plt.savefig(plots_dir + "data_mc_comparison_" + run + "_" + variable + "_.png")
plt.show()
# Out:
# Showing results for: run1
# Number of neutrinos: 1353.3311652726084
# Number of dirt: 376.5371383053959
# Number of beam-off: 2574.2379858691797
# Number of beam-on: 4299

# %%
up_plot = 120.
down_plot = -120.
my_custom_bins = np.linspace(down_plot,up_plot,20)
variable = 'reco_vertex_y'

#(counts_signal, bins_signal) = np.histogram(df_signal[variable], bins = my_custom_bins)
(counts_nu, bins_nu) = np.histogram(df_nu[variable], bins = my_custom_bins, weights = df_nu['weight'])
(counts_dirt, bins_dirt) = np.histogram(df_dirt[variable], bins = my_custom_bins, weights = df_dirt['weight'])
(counts_beamoff, bins_beamoff) = np.histogram(df_beamoff[variable], bins = my_custom_bins)
(counts_beamon, bins_beamon) = np.histogram(df_beamon[variable], bins = my_custom_bins)

print("Showing results for: " + run)
#print("Number of dark tridents M_A="+str(mass)+" :" + str(np.sum(counts_signal)*signal_scaling))
print("Number of neutrinos: " + str(np.sum(counts_nu)*nu_scaling))
print("Number of dirt: " + str(np.sum(counts_dirt)*dirt_scaling))
print("Number of beam-off: " + str(np.sum(counts_beamoff)*offbeam_scaling))
print("Number of beam-on: " + str(np.sum(counts_beamon)))


nu_legend = r'in cryo $\nu$ ({:.2f})'.format(np.sum(counts_nu)*nu_scaling)
dirt_legend = r'out of cryo $\nu$ ({:.2f})'.format(np.sum(counts_dirt)*dirt_scaling)
beamoff_legend = r'beam-off ({:.2f})'.format(np.sum(counts_beamoff)*offbeam_scaling)
beamon_legend = r'beam-on ({:.2f})'.format(np.sum(counts_beamon))

stacked_colors = ["darkviolet","navy","deepskyblue"]
stacked_legend = [nu_legend, dirt_legend, beamoff_legend]
stacked_bins = [bins_nu[:-1], bins_dirt[:-1], bins_beamoff[:-1]]
stacked_list = [counts_nu*nu_scaling, counts_dirt*dirt_scaling, counts_beamoff*offbeam_scaling ]


# Getting stats error 
counts_bkg = counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling
stats_nu = GetStatsUncert(df_nu, df_nu['weight']*nu_scaling,my_custom_bins,variable)
stats_dirt = GetStatsUncert(df_dirt, df_dirt['weight']*dirt_scaling,my_custom_bins,variable)
stats_beamoff = GetStatsUncert(df_beamoff, np.ones(len(df_beamoff))*offbeam_scaling,my_custom_bins,variable)
stats_total = np.sqrt(stats_nu + stats_dirt + stats_beamoff)
stats_error = (stats_total)/(counts_bkg)
stats_up = counts_bkg + stats_total
stats_down = counts_bkg - stats_total



# Trick for right error band on histograms 
bins_err = np.copy(bins_nu)
bins_err = np.append(bins_err,[bins_err[-1] + (bins_err[2] - bins_err[1])])
stats_up = np.append(stats_up,[stats_up[-1],stats_up[-1] ])
stats_down = np.append(stats_down,[stats_down[-1],stats_up[-1]])



fig, ax = plt.subplots(2,1,figsize=(10,7),dpi=300,gridspec_kw={'height_ratios': [4, 1], 'hspace': 0.08})
ax[0].set_title(r'MicroBooNE NuMI data' + ' ' + run + ', ' + dm_type + ' DM' + pot_label ,fontsize=15)
ax[0].hist(stacked_bins, bins = bins_nu, weights = stacked_list, histtype='stepfilled',stacked=True, color = stacked_colors, edgecolor="darkred", label = stacked_legend)
ax[0].fill_between(bins_err, stats_up, stats_down,color='gray',alpha=0.3,step='post')
ax[0].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),counts_beamon,yerr=np.sqrt(counts_beamon),fmt='o', capsize=5, color='black',label=beamon_legend)
#plt.hist(bins_signal[:-1], bins = bins_signal,weights=counts_signal*signal_scaling*10, histtype='step',label=dt_legend ,fill=False, edgecolor='gold', linewidth='2.')
ax[0].legend(fontsize=10)
ax[0].tick_params(axis='y', which='major', labelsize=10)
ax[0].tick_params(axis='x',which='both', bottom=False,top=False,labelbottom=False)
ax[0].set_xlim(down_plot,up_plot)
ax[0].set_ylabel("Events",fontsize=15, labelpad=7) 


ratio = (counts_beamon)/(counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling )
ax[1].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),ratio,fmt='o',capsize=5,color='black')
ax[1].hlines(1.0,down_plot,up_plot,color='black',linewidth=0.8)
ax[1].hlines(1.25,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].hlines(0.75,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].tick_params(axis='both', which='major', labelsize=10)
ax[1].set_ylim(0.5,1.5)
ax[1].set_xlabel(r'Reconstructed vertex y-coordinate [cm]',fontsize=15,labelpad=7)
ax[1].set_xlim(down_plot,up_plot)
ax[1].set_ylabel(r'Data/MC',fontsize=15,labelpad=7)
plt.savefig(plots_dir + "data_mc_comparison_" + run + "_" + variable + "_.png")
plt.show()
# Out:
# Showing results for: run1
# Number of neutrinos: 1347.8608900136564
# Number of dirt: 379.54155372454824
# Number of beam-off: 2566.92669801879
# Number of beam-on: 4271

# %%
up_plot = 1050
down_plot = 0.
my_custom_bins = np.linspace(down_plot,up_plot,20)
variable = 'reco_vertex_z'

#(counts_signal, bins_signal) = np.histogram(df_signal[variable], bins = my_custom_bins)
(counts_nu, bins_nu) = np.histogram(df_nu[variable], bins = my_custom_bins, weights = df_nu['weight'])
(counts_dirt, bins_dirt) = np.histogram(df_dirt[variable], bins = my_custom_bins, weights = df_dirt['weight'])
(counts_beamoff, bins_beamoff) = np.histogram(df_beamoff[variable], bins = my_custom_bins)
(counts_beamon, bins_beamon) = np.histogram(df_beamon[variable], bins = my_custom_bins)

print("Showing results for: " + run)
#print("Number of dark tridents M_A="+str(mass)+" :" + str(np.sum(counts_signal)*signal_scaling))
print("Number of neutrinos: " + str(np.sum(counts_nu)*nu_scaling))
print("Number of dirt: " + str(np.sum(counts_dirt)*dirt_scaling))
print("Number of beam-off: " + str(np.sum(counts_beamoff)*offbeam_scaling))
print("Number of beam-on: " + str(np.sum(counts_beamon)))


nu_legend = r'in cryo $\nu$ ({:.2f})'.format(np.sum(counts_nu)*nu_scaling)
dirt_legend = r'out of cryo $\nu$ ({:.2f})'.format(np.sum(counts_dirt)*dirt_scaling)
beamoff_legend = r'beam-off ({:.2f})'.format(np.sum(counts_beamoff)*offbeam_scaling)
beamon_legend = r'beam-on ({:.2f})'.format(np.sum(counts_beamon))

stacked_colors = ["darkviolet","navy","deepskyblue"]
stacked_legend = [nu_legend, dirt_legend, beamoff_legend]
stacked_bins = [bins_nu[:-1], bins_dirt[:-1], bins_beamoff[:-1]]
stacked_list = [counts_nu*nu_scaling, counts_dirt*dirt_scaling, counts_beamoff*offbeam_scaling ]


# Getting stats error 
counts_bkg = counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling
stats_nu = GetStatsUncert(df_nu, df_nu['weight']*nu_scaling,my_custom_bins,variable)
stats_dirt = GetStatsUncert(df_dirt, df_dirt['weight']*dirt_scaling,my_custom_bins,variable)
stats_beamoff = GetStatsUncert(df_beamoff, np.ones(len(df_beamoff))*offbeam_scaling,my_custom_bins,variable)
stats_total = np.sqrt(stats_nu + stats_dirt + stats_beamoff)
stats_error = (stats_total)/(counts_bkg)
stats_up = counts_bkg + stats_total
stats_down = counts_bkg - stats_total



# Trick for right error band on histograms 
bins_err = np.copy(bins_nu)
bins_err = np.append(bins_err,[bins_err[-1] + (bins_err[2] - bins_err[1])])
stats_up = np.append(stats_up,[stats_up[-1],stats_up[-1] ])
stats_down = np.append(stats_down,[stats_down[-1],stats_up[-1]])


fig, ax = plt.subplots(2,1,figsize=(10,7),dpi=300,gridspec_kw={'height_ratios': [4, 1], 'hspace': 0.08})
ax[0].set_title(r'MicroBooNE NuMI data' + ' ' + run + ', ' + dm_type + ' DM' + pot_label ,fontsize=15)
ax[0].hist(stacked_bins, bins = bins_nu, weights = stacked_list, histtype='stepfilled',stacked=True, color = stacked_colors, edgecolor="darkred", label = stacked_legend)
ax[0].fill_between(bins_err, stats_up, stats_down,color='gray',alpha=0.3,step='post')
ax[0].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),counts_beamon,yerr=np.sqrt(counts_beamon),fmt='o', capsize=5, color='black',label=beamon_legend)
#plt.hist(bins_signal[:-1], bins = bins_signal,weights=counts_signal*signal_scaling*10, histtype='step',label=dt_legend ,fill=False, edgecolor='gold', linewidth='2.')
ax[0].legend(fontsize=10)
ax[0].tick_params(axis='y', which='major', labelsize=10)
ax[0].tick_params(axis='x',which='both', bottom=False,top=False,labelbottom=False)
ax[0].set_xlim(down_plot,up_plot)
ax[0].set_ylabel("Events",fontsize=15, labelpad=7) 


ratio = (counts_beamon)/(counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling )
ax[1].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),ratio,fmt='o',capsize=5,color='black')
ax[1].hlines(1.0,down_plot,up_plot,color='black',linewidth=0.8)
ax[1].hlines(1.25,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].hlines(0.75,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].tick_params(axis='both', which='major', labelsize=10)
ax[1].set_ylim(0.5,1.5)
ax[1].set_xlabel(r'Reconstructed vertex z-coordinate [cm]',fontsize=15,labelpad=7)
ax[1].set_xlim(down_plot,up_plot)
ax[1].set_ylabel(r'Data/MC',fontsize=15,labelpad=7)
plt.savefig(plots_dir + "data_mc_comparison_" + run + "_" + variable + "_.png")
plt.show()
# Out:
# Showing results for: run1
# Number of neutrinos: 1367.7890698842548
# Number of dirt: 384.17924341791564
# Number of beam-off: 2618.105712971521
# Number of beam-on: 4368

# %%
up_plot = 800.
down_plot = 0.
my_custom_bins = np.linspace(down_plot,up_plot,20)
variable = 'reco_shower_energy_max'

#(counts_signal, bins_signal) = np.histogram(df_signal[variable], bins = my_custom_bins)
(counts_nu, bins_nu) = np.histogram(df_nu[variable], bins = my_custom_bins, weights = df_nu['weight'])
(counts_dirt, bins_dirt) = np.histogram(df_dirt[variable], bins = my_custom_bins, weights = df_dirt['weight'])
(counts_beamoff, bins_beamoff) = np.histogram(df_beamoff[variable], bins = my_custom_bins)
(counts_beamon, bins_beamon) = np.histogram(df_beamon[variable], bins = my_custom_bins)

print("Showing results for: " + run)
#print("Number of dark tridents M_A="+str(mass)+" :" + str(np.sum(counts_signal)*signal_scaling))
print("Number of neutrinos: " + str(np.sum(counts_nu)*nu_scaling))
print("Number of dirt: " + str(np.sum(counts_dirt)*dirt_scaling))
print("Number of beam-off: " + str(np.sum(counts_beamoff)*offbeam_scaling))
print("Number of beam-on: " + str(np.sum(counts_beamon)))


nu_legend = r'in cryo $\nu$ ({:.2f})'.format(np.sum(counts_nu)*nu_scaling)
dirt_legend = r'out of cryo $\nu$ ({:.2f})'.format(np.sum(counts_dirt)*dirt_scaling)
beamoff_legend = r'beam-off ({:.2f})'.format(np.sum(counts_beamoff)*offbeam_scaling)
beamon_legend = r'beam-on ({:.2f})'.format(np.sum(counts_beamon))

stacked_colors = ["darkviolet","navy","deepskyblue"]
stacked_legend = [nu_legend, dirt_legend, beamoff_legend]
stacked_bins = [bins_nu[:-1], bins_dirt[:-1], bins_beamoff[:-1]]
stacked_list = [counts_nu*nu_scaling, counts_dirt*dirt_scaling, counts_beamoff*offbeam_scaling ]

# Getting stats error 
counts_bkg = counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling
stats_nu = GetStatsUncert(df_nu, df_nu['weight']*nu_scaling,my_custom_bins,variable)
stats_dirt = GetStatsUncert(df_dirt, df_dirt['weight']*dirt_scaling,my_custom_bins,variable)
stats_beamoff = GetStatsUncert(df_beamoff, np.ones(len(df_beamoff))*offbeam_scaling,my_custom_bins,variable)
stats_total = np.sqrt(stats_nu + stats_dirt + stats_beamoff)
stats_error = (stats_total)/(counts_bkg)
stats_up = counts_bkg + stats_total
stats_down = counts_bkg - stats_total



# Trick for right error band on histograms 
bins_err = np.copy(bins_nu)
bins_err = np.append(bins_err,[bins_err[-1] + (bins_err[2] - bins_err[1])])
stats_up = np.append(stats_up,[stats_up[-1],stats_up[-1] ])
stats_down = np.append(stats_down,[stats_down[-1],stats_up[-1]])


fig, ax = plt.subplots(2,1,figsize=(10,7),dpi=300,gridspec_kw={'height_ratios': [4, 1], 'hspace': 0.08})
ax[0].set_title(r'MicroBooNE NuMI data' + ' ' + run + ', ' + dm_type + ' DM' + pot_label ,fontsize=15)
ax[0].hist(stacked_bins, bins = bins_nu, weights = stacked_list, histtype='stepfilled',stacked=True, color = stacked_colors, edgecolor="darkred", label = stacked_legend)
ax[0].fill_between(bins_err, stats_up, stats_down,color='gray',alpha=0.3,step='post')
ax[0].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),counts_beamon,yerr=np.sqrt(counts_beamon),fmt='o', capsize=5, color='black',label=beamon_legend)
#plt.hist(bins_signal[:-1], bins = bins_signal,weights=counts_signal*signal_scaling*10, histtype='step',label=dt_legend ,fill=False, edgecolor='gold', linewidth='2.')
ax[0].legend(fontsize=10)
ax[0].tick_params(axis='y', which='major', labelsize=10)
ax[0].tick_params(axis='x',which='both', bottom=False,top=False,labelbottom=False)
ax[0].set_xlim(down_plot,up_plot)
ax[0].set_ylabel("Events",fontsize=15, labelpad=7) 


ratio = (counts_beamon)/(counts_nu*nu_scaling + counts_dirt*dirt_scaling + counts_beamoff*offbeam_scaling )
ax[1].errorbar(bins_beamon[:-1]+ 0.5*(bins_beamon[1:] - bins_beamon[:-1]),ratio,fmt='o',capsize=5,color='black')
ax[1].hlines(1.0,down_plot,up_plot,color='black',linewidth=0.8)
ax[1].hlines(1.25,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].hlines(0.75,down_plot,up_plot,color='black',linestyle="--",linewidth=0.8)
ax[1].tick_params(axis='both', which='major', labelsize=10)
ax[1].set_ylim(0.5,1.5)
ax[1].set_xlabel(r'Total reconstructed energy [MeV]',fontsize=15,labelpad=7)
ax[1].set_xlim(down_plot,up_plot)
ax[1].set_ylabel(r'Data/MC',fontsize=15,labelpad=7)
plt.savefig(plots_dir + "data_mc_comparison_" + run + "_" + variable + "_.png")
plt.show()
# Out:
# Showing results for: run1
# Number of neutrinos: 1231.291632433499
# Number of dirt: 371.17944098863205
# Number of beam-off: 2408.7370154376217
# Number of beam-on: 4040
