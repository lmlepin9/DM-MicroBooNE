# %%
import uproot as u
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from global_settings import *

# %%
def logit_transform(score):
    return np.log(score/(1-score))

def filter_df(df):
    df = df[df['signal_score'] >= 0.5]
    return df

def GetStatsUncert(df_a, weight_array,my_custom_bins,plot_var):
    (counts_df, bins_df) = np.histogram(df_a[plot_var], bins = my_custom_bins, weights=np.square(weight_array))
    return counts_df

# %%
run="run1"
dm_type = 'fermion'
ratio = "2.0"



target_pot=0

scalar_factors = np.array([0.04444236, 0.03876295, 0.03149615, 0.03032621, 0.02560909, 0.02296708,
 0.0244469, 0.02523209, 0.03118899, 0.03338144, 0.02626005, 0.01194017,
 0.0040589 ])

    
if(run=="run1"):
    target_pot = 2.38e20
    
else:
    target_pot = 5.18e20 
    
print("Processing Run: ", run)
print("Target POT: ", target_pot)
# Out:
# Processing Run:  run1
# Target POT:  2.38e+20

# %%
base_dir = "/home/lmlepin/Desktop/dm_sets/dark_tridents_analysis/{}_signal/".format(run)

# %%
def MakeSignalHist(run,dm_type,ratio,mass,dmode):
    my_custom_bins = final_custom_bins
    df_signal = pd.read_csv(base_dir + "{}_dt_ratio_{}_{}_{}_CNN_scores_8441_steps.csv".format(run,ratio,mass,dmode))
    df_signal = df_signal.drop_duplicates()
    signal_fraction = len(df_signal)/len(df_signal[df_signal['signal_score']>= 0.])
    signal_scaling = (meson_scalings[dmode]*signal_fraction*target_pot)/(df_signal['total_pot'][0])
    
    print("For mass, decay mode "+ mass + " " + dmode)
    print("1e21 Number of events as a reference: ", 1e21/df_signal['mctruth_w'][0])
    
    if(ratio==str(0.6)):
        signal_scaling*=correction_dic_a[dmode][mass]
    else:
        signal_scaling*=correction_dic_b[dmode][mass]
        
    if(dm_type == "scalar" and ratio == str(0.6)):
        signal_scaling*=scalar_dic_a[dmode][mass]
    elif(dm_type == "scalar" and ratio == str(2.0)):
        signal_scaling*=scalar_dic_b[dmode][mass]

    df_signal = filter_df(df_signal)
    df_signal['signal_score'] = logit_transform(df_signal['signal_score'])
    (counts_signal_temp, bins_signal) = np.histogram(df_signal['signal_score'], bins = my_custom_bins )
    stats_uncert_temp = GetStatsUncert(df_signal,np.ones(len(df_signal))*signal_scaling,my_custom_bins,'signal_score')
    return (counts_signal_temp,stats_uncert_temp,bins_signal,signal_scaling)

# %%
def MakeSignalFile(run,dm_type,ratio):
    my_custom_bins = final_custom_bins
    signal_file = u.recreate(base_dir + "{}_ratio_{}_signal_hist_{}_CNN.root".format(dm_type,ratio,run))
    
    # Retrieve array of masses 
    masses = mass_dic[ratio]
    
    # Decay types
    decays = ["pi0", "eta"]
    
    
    # Retrieve dictionary with xsec uncerts
    if(run=="run1" and ratio == "0.6"):
        xsec_uncertainties = run1_xsec_uncert_a
    elif(run=="run3" and ratio == "0.6"):
        xsec_uncertainties = run3_xsec_uncert_a
    elif(run=="run1" and ratio == "2.0"):
        xsec_uncertainties = run1_xsec_uncert_b
    elif(run=="run3" and ratio == "2.0"):
        xsec_uncertainties = run3_xsec_uncert_b
    
    # Create a histogram for each mass point 
    for mass in masses:        
        counts_signal = np.zeros(len(my_custom_bins) - 1) 
        stats_uncert = np.zeros(len(my_custom_bins) - 1)
        xsec_uncert  = 0
        #xsec_uncert = np.sqrt()
        
        
        if(ratio == "0.6"):
            if(float(mass) > 0.01 and float(mass)< 0.1):
                for dmode in decays:
                    # Adding xsec error in quadrature
                    xsec_uncert += np.square(xsec_uncertainties[dmode][mass])
                    (counts_signal_temp, stats_uncert_temp, bins_signal,signal_scaling) = MakeSignalHist(run,dm_type,ratio,mass,dmode)
                    counts_signal+=counts_signal_temp*signal_scaling
                    stats_uncert+=stats_uncert_temp


            elif(float(mass) == 0.01):
                dmode=decays[0]
                # Adding xsec error in quadrature
                xsec_uncert += np.square(xsec_uncertainties[dmode][mass])
                (counts_signal_temp, stats_uncert_temp, bins_signal,signal_scaling) = MakeSignalHist(run,dm_type,ratio,mass,dmode)
                counts_signal+=counts_signal_temp*signal_scaling
                stats_uncert+=stats_uncert_temp

            elif(float(mass) >= 0.1):
                dmode=decays[1]
                # Adding xsec error in quadrature
                xsec_uncert += np.square(xsec_uncertainties[dmode][mass])
                (counts_signal_temp, stats_uncert_temp, bins_signal,signal_scaling) = MakeSignalHist(run,dm_type,ratio,mass,dmode)
                counts_signal+=counts_signal_temp*signal_scaling
                stats_uncert+=stats_uncert_temp
        else:
            if(float(mass) <= 0.03):
                for dmode in decays:
                    # Adding xsec error in quadrature
                    xsec_uncert += np.square(xsec_uncertainties[dmode][mass])
                    (counts_signal_temp, stats_uncert_temp, bins_signal,signal_scaling) = MakeSignalHist(run,dm_type,ratio,mass,dmode)
                    counts_signal+=counts_signal_temp*signal_scaling
                    stats_uncert+=stats_uncert_temp
                
            else:
                dmode=decays[1]
                # Adding xsec error in quadrature
                xsec_uncert += np.square(xsec_uncertainties[dmode][mass])
                (counts_signal_temp, stats_uncert_temp, bins_signal,signal_scaling) = MakeSignalHist(run,dm_type,ratio,mass,dmode)
                counts_signal+=counts_signal_temp*signal_scaling
                stats_uncert+=stats_uncert_temp
        
        
        # Total uncertainty in %
        total_uncert = np.sqrt((stats_uncert/(counts_signal))*100 + np.ones(len(bins_signal)-1)*xsec_uncert + np.ones(len(bins_signal)-1)*(detvar_uncert*100)**2)
        stats_uncert = np.sqrt(stats_uncert)
        xsec_uncert = np.sqrt(xsec_uncert)
        
        print("Mass: " + mass)
        print("Total events for target POT: ", np.sum(counts_signal))
        print("Statistical uncertainty: ",stats_uncert)
        print("CV bins: ", counts_signal)
        print("Statistical fractional error: ", (stats_uncert/(counts_signal))*100)
        print("xsec error: ", xsec_uncert)
        print("Total error: ", total_uncert)
        print("\n")
        signal_file["signal_"+mass] = (counts_signal, bins_signal)
        signal_file["signal_mc_error_"+mass] = (stats_uncert, bins_signal)
        signal_file["signal_xsec_error_"+mass] = (np.ones(len(bins_signal)-1)*xsec_uncert,bins_signal)
        signal_file["signal_det_uncert_"+mass] = (np.ones(len(bins_signal)-1)*detvar_uncert,bins_signal)
        signal_file["signal_total_error_"+mass] = (total_uncert, bins_signal)

# %%
MakeSignalFile(run,dm_type,ratio)
# Out:
# For mass, decay mode 0.010 pi0
# 1e21 Number of events as a reference:  2763.9656273234586
# For mass, decay mode 0.010 eta
# 1e21 Number of events as a reference:  664.4827334161722
# Mass: 0.010
# Total events for target POT:  25683.10945951785
# Statistical uncertainty:  [167.75493895 185.31864217 197.30410383 177.9863639  124.57188505]
# CV bins:  [4816.29420032 5899.60708213 6734.01638478 5492.20909344 2740.98269884]
# Statistical fractional error:  [3.48307084 3.14120313 2.92996174 3.24070626 4.54478918]
# xsec error:  1.9720796506246085
# Total error:  [30.20250709 30.16641504 30.09954442 30.07807543 29.900536  ]
#
#
# For mass, decay mode 0.020 pi0
# 1e21 Number of events as a reference:  45.91073117430468
# For mass, decay mode 0.020 eta
# 1e21 Number of events as a reference:  86.12374259335813
# Mass: 0.020
# Total events for target POT:  640.2975779849525
# Statistical uncertainty:  [3.09568509 3.5635098  3.79874689 3.603713   2.64316582]
# CV bins:  [109.4042223  144.22666491 164.01316849 145.11641218  77.53711009]
# Statistical fractional error:  [2.82958466 2.47077043 2.3161231  2.48332559 3.40890423]
# xsec error:  4.169448413615836
# Total error:  [18.71212984 18.71333521 18.71316824 18.71719778 18.71883007]
#
#
# For mass, decay mode 0.030 pi0
# 1e21 Number of events as a reference:  0.04789226156837578
# For mass, decay mode 0.030 eta
# 1e21 Number of events as a reference:  14.239071156910292
# Mass: 0.030
# Total events for target POT:  57.46705671899794
# Statistical uncertainty:  [0.38494044 0.47824976 0.50695741 0.48811159 0.36018381]
# CV bins:  [ 8.5072856  13.11742338 14.73985747 13.6637791   7.43871117]
# Statistical fractional error:  [4.52483273 3.64591237 3.4393644  3.57230301 4.84201902]
# xsec error:  6.131230133449739
# Total error:  [19.06131617 19.06136511 19.06136391 19.06136578 19.06137455]
#
#
# For mass, decay mode 0.040 eta
# 1e21 Number of events as a reference:  3.705254421294838
# Mass: 0.040
# Total events for target POT:  14.179373868814556
# Statistical uncertainty:  [0.1410883  0.1670776  0.17942014 0.16984703 0.12717527]
# CV bins:  [2.25741276 3.16566867 3.65065969 3.27148489 1.83414786]
# Statistical fractional error:  [6.25       5.27779814 4.91473187 5.19174132 6.93375245]
# xsec error:  4.668685966918998
# Total error:  [18.61930263 18.61930263 18.61930263 18.61930263 18.61930263]
#
#
# For mass, decay mode 0.050 eta
# 1e21 Number of events as a reference:  1.1999659209678446
# Mass: 0.050
# Total events for target POT:  4.784701194888348
# Statistical uncertainty:  [0.03063397 0.0360546  0.0384044  0.03516122 0.02835426]
# CV bins:  [0.78041495 1.08103704 1.22653813 1.02812755 0.66858353]
# Statistical fractional error:  [3.92534336 3.33518673 3.13112146 3.41992784 4.24094465]
# xsec error:  7.009216239713371
# Total error:  [19.31966255 19.31966255 19.31966255 19.31966255 19.31966255]
#
#
# For mass, decay mode 0.060 eta
# 1e21 Number of events as a reference:  0.36320184215974344
# Mass: 0.060
# Total events for target POT:  1.149999981018783
# Statistical uncertainty:  [0.0079674  0.00945473 0.01023552 0.00982767 0.00712104]
# CV bins:  [0.18028169 0.25387324 0.29753521 0.27429577 0.14401408]
# Statistical fractional error:  [4.41941738 3.72419461 3.44010458 3.58287182 4.94468176]
# xsec error:  7.840022757040903
# Total error:  [19.63418366 19.63418366 19.63418366 19.63418366 19.63418366]
#
#
# For mass, decay mode 0.065 eta
# 1e21 Number of events as a reference:  0.16225785044044894
# Mass: 0.065
# Total events for target POT:  0.525558172870947
# Statistical uncertainty:  [0.0036212  0.00435861 0.00467585 0.00434404 0.0032948 ]
# CV bins:  [0.08233745 0.11928578 0.13728217 0.11848948 0.0681633 ]
# Statistical fractional error:  [4.39799497 3.65392048 3.40601352 3.66617788 4.83368245]
# xsec error:  7.313574977116353
# Total error:  [19.42947001 19.42947001 19.42947001 19.42947001 19.42947001]
#
#
# For mass, decay mode 0.070 eta
# 1e21 Number of events as a reference:  0.08435259384226065
# Mass: 0.070
# Total events for target POT:  0.267974860548144
# Statistical uncertainty:  [0.0021985  0.00250438 0.0026926  0.00262113 0.00187656]
# CV bins:  [0.04505582 0.05846529 0.06758373 0.06404363 0.03282638]
# Statistical fractional error:  [4.87950036 4.28352937 3.98409536 4.09272755 5.7166195 ]
# xsec error:  8.01118023073866
# Total error:  [19.70253121 19.70253121 19.70253121 19.70253121 19.70253121]
#
#
# For mass, decay mode 0.075 eta
# 1e21 Number of events as a reference:  0.04552386588669109
# Mass: 0.075
# Total events for target POT:  0.14755671825559552
# Statistical uncertainty:  [0.0009097  0.00108591 0.00115252 0.00108991 0.00082368]
# CV bins:  [0.02347653 0.0334523  0.03768231 0.03369905 0.01924653]
# Statistical fractional error:  [3.87492129 3.24613737 3.05851875 3.23423114 4.27960493]
# xsec error:  8.525720251239436
# Total error:  [19.91711402 19.91711402 19.91711402 19.91711402 19.91711402]
#
#
# For mass, decay mode 0.080 eta
# 1e21 Number of events as a reference:  0.02559967232419425
# Mass: 0.080
# Total events for target POT:  0.07648620587664993
# Statistical uncertainty:  [0.00064097 0.00077177 0.00080012 0.00074962 0.00055949]
# CV bins:  [0.01246198 0.01806657 0.01941827 0.01704456 0.00949484]
# Statistical fractional error:  [5.143445   4.27178829 4.12042822 4.39799497 5.89255651]
# xsec error:  8.776103031617431
# Total error:  [20.02556569 20.02556569 20.02556569 20.02556569 20.02556569]
#
#
# For mass, decay mode 0.085 eta
# 1e21 Number of events as a reference:  0.013148137434850977
# Mass: 0.085
# Total events for target POT:  0.03401970468256469
# Statistical uncertainty:  [0.00032006 0.00035859 0.0003664  0.00035291 0.00026219]
# CV bins:  [0.00623914 0.00783176 0.00817655 0.00758547 0.00418679]
# Statistical fractional error:  [5.12989176 4.57868546 4.48110715 4.65242105 6.26224291]
# xsec error:  10.444133955025494
# Total error:  [20.8106121 20.8106121 20.8106121 20.8106121 20.8106121]
#
#
# For mass, decay mode 0.090 eta
# 1e21 Number of events as a reference:  0.005816286766202721
# Mass: 0.090
# Total events for target POT:  0.020377390636641457
# Statistical uncertainty:  [0.0001671  0.00018601 0.00019576 0.00017588 0.00013783]
# CV bins:  [0.00377359 0.00467629 0.00517944 0.00418055 0.00256752]
# Statistical fractional error:  [4.42807443 3.97778642 3.77964473 4.20703162 5.36828127]
# xsec error:  10.866147859164696
# Total error:  [21.02555372 21.02555372 21.02555372 21.02555372 21.02555372]
#
#
# For mass, decay mode 0.095 eta
# 1e21 Number of events as a reference:  0.0030429358244834616
# Mass: 0.095
# Total events for target POT:  0.007481351446967358
# Statistical uncertainty:  [5.57731905e-05 6.48976898e-05 6.79768174e-05 6.44324674e-05
#  4.75002452e-05]
# CV bins:  [0.00126815 0.00171703 0.00188383 0.0016925  0.00091984]
# Statistical fractional error:  [4.39799497 3.77964473 3.60843918 3.80693494 5.16397779]
# xsec error:  10.915534355482889
# Total error:  [21.0511077 21.0511077 21.0511077 21.0511077 21.0511077]
#
#
# For mass, decay mode 0.100 eta
# 1e21 Number of events as a reference:  0.001247282483289533
# Mass: 0.100
# Total events for target POT:  0.003892187776986045
# Statistical uncertainty:  [2.90249456e-05 3.39079035e-05 3.52517370e-05 3.09495034e-05
#  2.39295724e-05]
# CV bins:  [0.00068808 0.00093907 0.00101498 0.00078236 0.0004677 ]
# Statistical fractional error:  [4.21824541 3.61079072 3.47314356 3.95593886 5.1164451 ]
# xsec error:  12.594004689855332
# Total error:  [21.96836536 21.96836536 21.96836536 21.96836536 21.96836536]
#
#
# For mass, decay mode 0.105 eta
# 1e21 Number of events as a reference:  0.00048315480763191335
# Mass: 0.105
# Total events for target POT:  0.0014268210262250555
# Statistical uncertainty:  [1.05628412e-05 1.29129654e-05 1.35641303e-05 1.23773264e-05
#  9.62333433e-06]
# CV bins:  [0.00022482 0.00033599 0.00037073 0.00030869 0.0001866 ]
# Statistical fractional error:  [4.69840986 3.84331221 3.65880867 4.0096347  5.15710623]
# xsec error:  12.122315090335528
# Total error:  [21.70139564 21.70139564 21.70139564 21.70139564 21.70139564]
#
#
# For mass, decay mode 0.110 eta
# 1e21 Number of events as a reference:  0.00019827264868465925
# Mass: 0.110
# Total events for target POT:  0.00048447393447701977
# Statistical uncertainty:  [3.51601786e-06 4.00008468e-06 4.07997322e-06 3.86326769e-06
#  2.79719362e-06]
# CV bins:  [8.83913183e-05 1.14405219e-04 1.19020588e-04 1.06712936e-04
#  5.59438723e-05]
# Statistical fractional error:  [3.97778642 3.49641801 3.42795585 3.62024307 5.        ]
# xsec error:  12.784987613655291
# Total error:  [22.07840398 22.07840398 22.07840398 22.07840398 22.07840398]
# For mass, decay mode 0.115 eta
# 1e21 Number of events as a reference:  6.717044500419816e-05
# Mass: 0.115
# Total events for target POT:  0.000183255272307238
# Statistical uncertainty:  [1.40890554e-06 1.61080661e-06 1.69967805e-06 1.47767259e-06
#  1.12176540e-06]
# CV bins:  [3.33407903e-05 4.35811759e-05 4.85227573e-05 3.66748693e-05
#  2.11356796e-05]
# Statistical fractional error:  [4.22577127 3.69610635 3.50284722 4.02911482 5.30744892]
# xsec error:  12.69399184519348
# Total error:  [22.02583562 22.02583562 22.02583562 22.02583562 22.02583562]
#
#
# For mass, decay mode 0.120 eta
# 1e21 Number of events as a reference:  1.6647494302395075e-05
# Mass: 0.120
# Total events for target POT:  4.055862782036435e-05
# Statistical uncertainty:  [3.15571252e-07 3.66686091e-07 3.83101780e-07 3.30861211e-07
#  2.52176141e-07]
# CV bins:  [7.29235935e-06 9.84605073e-06 1.07473536e-05 8.01613284e-06
#  4.65673134e-06]
# Statistical fractional error:  [4.32742322 3.72419461 3.56461503 4.12744172 5.41530361]
# xsec error:  12.483917086072417
# Total error:  [21.90543739 21.90543739 21.90543739 21.90543739 21.90543739]
#
#
# For mass, decay mode 0.125 eta
# 1e21 Number of events as a reference:  2.384063015553627e-06
# Mass: 0.125
# Total events for target POT:  5.002233094748448e-06
# Statistical uncertainty:  [3.98245607e-08 4.53359920e-08 4.63398626e-08 4.45510416e-08
#  3.14292240e-08]
# CV bins:  [9.05516285e-07 1.17349306e-06 1.22603752e-06 1.13320897e-06
#  5.63977261e-07]
# Statistical fractional error:  [4.39799497 3.86333705 3.77964473 3.93140567 5.57278213]
# xsec error:  13.737889427732572
# Total error:  [22.64353343 22.64353343 22.64353343 22.64353343 22.64353343]
